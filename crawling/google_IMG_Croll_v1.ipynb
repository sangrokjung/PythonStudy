# %% [markdown]
# # Google Crawling

# %%
from selenium import webdriver
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
import os

# %%
def get_pic(driver, path, keyword, limit, option=1) :
    if not os.path.isdir(f"{keyword}/"):
        os.makedirs(f"{keyword}/")

    driver = webdriver.Chrome(driver)
    driver.get(path)

    search = keyword
    elem = driver.find_element_by_name("q")
    elem.send_keys(search)
    elem.send_keys(Keys.RETURN)
    count = 0

    SCROLL_PAUSE_TIME = 1
    
    new_keyword = keyword.replace(" ", '_')

    last_height = driver.execute_script("return document.body.scrollHeight")
    BT_see_more = '//*[@id="islmp"]/div/div/div/div/div[2]/span' # 
    BT_see_more2 = '//*[@id="islmp"]/div/div/div/div/div/div[2]/div[2]/input' # 결과 더 보기
    page = 0

    if option == 1:
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            time.sleep(1)
            print("page down")

            if new_height == last_height and page == 0 : #결과 더 보기
                element = driver.find_element_by_xpath(BT_see_more2)   
                element.click()
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)
                new_height = driver.execute_script("return document.body.scrollHeight")
                page += 1
                print(f"page : {page}")               

            if new_height == last_height and page == 1 : #페이지 다 내림 
                print(f"page : {page}")            
                try:
                    time.sleep(1)
                    # print("checkk point 0")                
                    # driver.find_element_by_css_selector(".mye4qd").click()
                    print("checkk point 1")
                    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
                    print("checkk point 2")


                    # //*[@id="islrg"]/div[1]/div[93]/a[1]/div[1]/img
                    for image in images:
                        print("checkk point 3")                     
                        try:
                            print("checkk point 4")                                             
                            image.click()
                            time.sleep(2)
                            count += 1
                            imgUrl = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{count}]/a[1]/div[1]/img").get_attribute('src')
                            lastImg = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{len(images)-1}]/a[1]/div[1]/img").get_attribute('src')
                            urllib.request.urlretrieve(imgUrl, f"{keyword}/" + new_keyword + "_" + str(count) + ".jpg")
                            print(f"Image saved: {keyword}{count}.jpg")
                            if count == limit : 
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()
                            if imgUrl == lastImg :
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()

                        except:
                            pass
                except:
                    print("ERROR BREAK!!")
                    break
            last_height = new_height
    elif option == 2 :
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            time.sleep(1)
            print("page down")

            if new_height == last_height and page == 0: # 나머지 검색결과는 내가 찾고 있는 항목이 아닐 수도 있습니다.
                print("if 1 start")
                element = driver.find_element_by_xpath(BT_see_more)   
                element.click()
                page += 1
                time.sleep(1)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)  
                new_height = driver.execute_script("return document.body.scrollHeight")            
                print(f"page : {page}")

            if new_height == last_height and page == 1 : #결과 더 보기
                element = driver.find_element_by_xpath(BT_see_more2)   
                element.click()
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)
                new_height = driver.execute_script("return document.body.scrollHeight")
                page += 1
                print(f"page : {page}")               

            if new_height == last_height and page == 2 : #페이지 다 내림 
                print(f"page : {page}")            
                try:
                    time.sleep(1)
                    # print("checkk point 0")                
                    # driver.find_element_by_css_selector(".mye4qd").click()
                    print("checkk point 1")
                    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
                    print("checkk point 2")                

                    # //*[@id="islrg"]/div[1]/div[93]/a[1]/div[1]/img
                    for image in images:
                        print("checkk point 3")                     
                        try:
                            print("checkk point 4")                                             
                            image.click()
                            time.sleep(2)
                            count += 1
                            print(count)
                            imgUrl = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{count}]/a[1]/div[1]/img").get_attribute('src')
jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈242.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈243.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈244.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈245.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈246.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈247.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈248.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈249.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈251.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈252.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈253.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈254.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈255.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈256.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈257.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈258.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈259.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈260.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈261.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈262.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈263.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈264.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈265.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈266.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈267.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈268.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈269.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈270.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈271.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈272.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈273.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈274.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈276.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈277.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈278.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈279.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈280.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈281.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈282.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈283.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈284.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈285.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈286.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈287.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈288.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈289.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈290.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈291.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈292.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈293.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈294.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈295.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈296.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈297.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈298.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈299.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈301.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈302.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈303.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈304.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈305.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈306.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈307.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈308.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈309.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈310.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈311.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈312.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈313.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈314.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈315.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈316.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈317.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈318.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈319.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈320.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈321.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈322.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈323.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈324.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈326.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈327.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈328.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈329.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈330.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈331.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈332.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈333.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈334.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈335.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈336.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# page down
# page down
# page : 1
# checkk point 1
# checkk point 2
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈377.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈378.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈379.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈380.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈381.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈382.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈383.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈384.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈385.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈386.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈387.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈388.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈389.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈390.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈391.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈392.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈393.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈394.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈395.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈396.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈397.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈398.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈399.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 문상훈401.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈402.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈403.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈404.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈405.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈406.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈407.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈408.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈409.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈410.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈411.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈412.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈413.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈414.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈415.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈416.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈417.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈418.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈419.jpg
# checkk point 3
# checkk point 4
# Image saved: 문상훈420.jpg
# Crawling succeeded, driver shutdown.
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/2251080406.py in <module>
#       5 option = 1
#       6
# ----> 7 get_pic(driver, path, keyword, limit, option)
#
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/544455079.py in get_pic(driver, path, keyword, limit, option)
#      23     if option == 1:
#      24         while True:
# ---> 25             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      26             time.sleep(SCROLL_PAUSE_TIME)
#      27             new_height = driver.execute_script("return document.body.scrollHeight")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     882         command = Command.W3C_EXECUTE_SCRIPT
#     883
# --> 884         return self.execute(command, {
#     885             'script': script,
#     886             'args': converted_args})['value']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 0   chromedriver                        0x000000010a8e0f38 chromedriver + 4910904
# 1   chromedriver                        0x000000010a860a03 chromedriver + 4385283
# 2   chromedriver                        0x000000010a4a55bd chromedriver + 472509
# 3   chromedriver                        0x000000010a4d998f chromedriver + 686479
# 4   chromedriver                        0x000000010a510016 chromedriver + 909334
# 5   chromedriver                        0x000000010a50bedd chromedriver + 892637
# 6   chromedriver                        0x000000010a50b1ff chromedriver + 889343
# 7   chromedriver                        0x000000010a470afa chromedriver + 256762
# 8   chromedriver                        0x000000010a8ae1de chromedriver + 4702686
# 9   chromedriver                        0x000000010a8b2b19 chromedriver + 4721433
# 10  chromedriver                        0x000000010a8ba28e chromedriver + 4752014
# 11  chromedriver                        0x000000010a8b391a chromedriver + 4725018
# 12  chromedriver                        0x000000010a887b02 chromedriver + 4545282
# 13  chromedriver                        0x000000010a46f237 chromedriver + 250423
# 14  dyld                                0x00007ff807de8310 start + 2432
