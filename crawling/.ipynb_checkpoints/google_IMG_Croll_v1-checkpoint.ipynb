# %% [markdown]
# # Google Crawling

# %%
from selenium import webdriver
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
import os

# %%
def get_pic(driver, path, keyword, limit, option=1) :
    if not os.path.isdir(f"{keyword}/"):
        os.makedirs(f"{keyword}/")

    driver = webdriver.Chrome(driver)
    driver.get(path)

    search = keyword
    elem = driver.find_element_by_name("q")
    elem.send_keys(search)
    elem.send_keys(Keys.RETURN)

    SCROLL_PAUSE_TIME = 1
    
    new_keyword = keyword.replace(" ", '_')

    last_height = driver.execute_script("return document.body.scrollHeight")
    BT_see_more = '//*[@id="islmp"]/div/div/div/div/div[2]/span' # 
    BT_see_more2 = '//*[@id="islmp"]/div/div/div/div/div/div[2]/div[2]/input' # 결과 더 보기
    page = 0

    if option == 1:
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            time.sleep(1)
            print("page down")

            if new_height == last_height and page == 0 : #결과 더 보기
                element = driver.find_element_by_xpath(BT_see_more2)   
                element.click()
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)
                new_height = driver.execute_script("return document.body.scrollHeight")
                page += 1
                print(f"page : {page}")               

            if new_height == last_height and page == 1 : #페이지 다 내림 
                print(f"page : {page}")            
                try:
                    time.sleep(1)
                    # print("checkk point 0")                
                    # driver.find_element_by_css_selector(".mye4qd").click()
                    print("checkk point 1")
                    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
                    print("checkk point 2")
                    count = 0

                    # //*[@id="islrg"]/div[1]/div[93]/a[1]/div[1]/img
                    for image in images:
                        print("checkk point 3")                     
                        try:
                            print("checkk point 4")                                             
                            image.click()
                            time.sleep(2)
                            count += 1
                            imgUrl = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{count}]/a[1]/div[1]/img").get_attribute('src')
                            lastImg = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{len(images)-1}]/a[1]/div[1]/img").get_attribute('src')
                            urllib.request.urlretrieve(imgUrl, f"{keyword}/" + new_keyword + "_" + str(count) + ".jpg")
                            print(f"Image saved: {keyword}{count}.jpg")
                            if count == limit : 
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()
                            if imgUrl == lastImg :
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()

                        except:
                            pass
                except:
                    print("ERROR BREAK!!")
                    break
            last_height = new_height
    elif option == 2 :
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            time.sleep(1)
            print("page down")

            if new_height == last_height and page == 0: # 나머지 검색결과는 내가 찾고 있는 항목이 아닐 수도 있습니다.
                print("if 1 start")
                element = driver.find_element_by_xpath(BT_see_more)   
                element.click()
                page += 1
                time.sleep(1)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)  
                new_height = driver.execute_script("return document.body.scrollHeight")            
                print(f"page : {page}")

            if new_height == last_height and page == 1 : #결과 더 보기
                element = driver.find_element_by_xpath(BT_see_more2)   
                element.click()
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(SCROLL_PAUSE_TIME)
                new_height = driver.execute_script("return document.body.scrollHeight")
                page += 1
                print(f"page : {page}")               

            if new_height == last_height and page == 2 : #페이지 다 내림 
                print(f"page : {page}")            
                try:
                    time.sleep(1)
                    # print("checkk point 0")                
                    # driver.find_element_by_css_selector(".mye4qd").click()
                    print("checkk point 1")
                    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
                    print("checkk point 2")                
                    count = 0

                    # //*[@id="islrg"]/div[1]/div[93]/a[1]/div[1]/img
                    for image in images:
                        print("checkk point 3")                     
                        try:
                            print("checkk point 4")                                             
                            image.click()
                            time.sleep(2)
                            count += 1
                            print(count)
                            imgUrl = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{count}]/a[1]/div[1]/img").get_attribute('src')
        #                     print(imgUrl)
                            urllib.request.urlretrieve(imgUrl, f"{keyword}/" + new_keyword + "_" + str(count) + ".jpg")
                            print(f"Image saved: {keyword}{count}.jpg")
                            if count == limit : 
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()            
                            if imgUrl == lastImg :
                                print("Crawling succeeded, driver shutdown.")
                                driver.close()                            

                        except:
                            pass
                except:
                    print("ERROR BREAK!!")
                    break
            last_height = new_height

# %% [markdown]
# #### option = 1,  "결과 더 보기"로 바로 이어지는 코드
# #### option = 2,  "나머지 검색결과는 내가 찾고 있는 항목이 아닐 수도 있습니다. 검색결과 더보기" 로 이어질때

# %%
driver = "/Users/werther/chromedriver" #chrome driver 위치
path = 'https://www.google.co.kr/imghp?hl=ko&ogbl'
keyword = '침착맨' 
limit = 400 # 추출할 데이터의 한도치
option = 1

get_pic(driver, path, keyword, limit, option)
# Out:
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver)
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:9: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   elem = driver.find_element_by_name("q")
# page down
# page down
# page down
# page down
# page down
# page down
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element = driver.find_element_by_xpath(BT_see_more2)
# page : 1
# page down
# page down
# page : 1
# checkk point 1
# checkk point 2
# checkk point 3
# checkk point 4
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:44: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:56: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   imgUrl = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{count}]/a[1]/div[1]/img").get_attribute('src')
# /var/folders/t4/vwr916y50fv3wcm0xlgfkyg00000gn/T/ipykernel_1618/659634044.py:57: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   lastImg = driver.find_element_by_xpath(f"//*[@id='islrg']/div[1]/div[{len(images)-1}]/a[1]/div[1]/img").get_attribute('src')
# Image saved: 침착맨1.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨2.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨3.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨4.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨5.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨6.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨7.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨8.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨9.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨10.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨11.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨12.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨13.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨14.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨15.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨16.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨17.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨18.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨19.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨20.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨21.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨22.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨23.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨24.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨26.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨27.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨28.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨29.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨30.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨31.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨32.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨33.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨34.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨35.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨36.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨37.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨38.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨39.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨40.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨41.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨42.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨43.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨44.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨45.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨46.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨47.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨48.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨49.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨51.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨52.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨53.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨54.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨55.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨56.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨57.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨58.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨59.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨60.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨61.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨62.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨63.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨64.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨65.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨66.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨67.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨68.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨69.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨70.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨71.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨72.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨73.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨74.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨76.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨77.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨78.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨79.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨80.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨81.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨82.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨83.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨84.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨85.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨86.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨87.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨88.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨89.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨90.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨91.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨92.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨93.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨94.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨95.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨96.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨97.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨98.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨99.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨101.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨102.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨103.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨104.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨105.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨106.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨107.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨108.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨109.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨110.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨111.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨112.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨113.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨114.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨115.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨116.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨117.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨118.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨119.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨120.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨121.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨122.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨123.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨124.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# Image saved: 침착맨126.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨127.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨128.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨129.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨130.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨131.jpg
# checkk point 3
# checkk point 4
# Image saved: 침착맨132.jpg
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
# checkk point 3
# checkk point 4
