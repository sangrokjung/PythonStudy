# %%
f = open("sample3.txt", "w")

f.write("처음으로 작성한 내용입니다.")

f.close()

f = open("sample3.txt", "a")

f.write("\n추가 작업한 내용입니다.")

f.close()

# 처음으로 작성한 내용입니다.
# 추가 작업한 내용입니다.

# %%
with open("sample3.txt", 'a') as f :
    f.write("\nwtih문을 사용하여 문자를 추가하였다.")
    
# 처음으로 작성한 내용입니다.
# 추가 작업한 내용입니다.
# wtih문을 사용하여 문자를 추가하였다.

# %%
with open("GUGUDan.txt", 'w') as f :
    num = int(input("1~9의 수를 입력하세요 : "))
    f.write(f"\n{num}단 시작\n")
    for i in range(1, 10) : 
        result = num * i
        data = f"{num} * {i} = {result}\n"
        f.write(data)
    f.write(f"{num}단 종료")
        
with open("GUGUDan.txt", "r") as f :
    line = f.readlines()
    for i in line :
        print(i.strip())

# 1~9의 수를 입력하세요 : 3

# 3단 시작
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3단 종료
# Out:
# 1~9의 수를 입력하세요 : 2
#
# 2단 시작
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2단 종료

# %%
import os

f = os.listdir("../werther/")

os.renames("../werther/GUGU_3Dan.txt", "../werther/GUGUDan.txt")
# Out:
# ['Untitled7.ipynb', '.config', 'scores.txt', 'Music', '.condarc', 'Untitled5.ipynb', 'Untitled1.ipynb', '.DS_Store', '.CFUserTextEncoding', '.xonshrc', 'Untitled3.ipynb', 'Untitled.ipynb', '.zshrc', 'Untitled4.ipynb', 'Untitled6.ipynb', 'Pictures', 'Untitled2.ipynb', '.ipython', 'Desktop', 'Library', '.bash_sessions', 'Public', 'GUGU_3Dan.txt', '.tcshrc', '.anaconda', 'Untitled8.ipynb', 'Movies', 'Applications', 'opt', '.Trash', 'Splice', '.ipynb_checkpoints', '.jupyter', 'Documents', '.vscode', '.bash_profile', 'Downloads', '.python_history', '.continuum', '.cache', '.gitconfig', 'sampl1.txt', '유승.txt', 'Untitled9.ipynb', '.bash_history', 'sample2.txt', '.conda', 'new.txt', 'sample3.txt']

# %%
with open("sample3.txt", "w") as f :
    f.write("예시 입니다.")

with open("sample3.txt", "r") as f :
    line = f.read()
    print(line)
# Out:
# 예시 입니다.

# %%
with open("조 나누기.txt", "w") as f :
    on_team = list()
    on_team4 = list() 
    on_team3 = list() 
    on_team2 = list() 
    on_team1 = list() 
    
    off_team = list()
    off_team4 = list() 
    off_team3 = list() 
    off_team2 = list() 
    off_team1 = list() 
    
    
    def rank(name, num, meet) : 
        global on_team1, on_team2, on_team3, on_team4, off_team1, off_team2, off_team3, off_team4
        if meet == "on" :
            if num == 1 : 
                on_team1 += [name]
            elif num == 2:
                on_team2 += [name]
            elif num == 3:
                on_team3 += [name]
            elif num == 4:
                on_team4 += [name]
        if meet == "off" :
            if num == 1 : 
                off_team1 += [name]
            elif num == 2:
                off_team2 += [name]
            elif num == 3:
                off_team3 += [name]
            elif num == 4:
                off_team4 += [name]
        else :
            print("다시 입력하세요 : ")
        
    s_num = int(input("학생수를 입력하세요 : "))
    
    for i in range(s_num) : 
        name = input("이름을 입력하세요 : ")
        meet = input("온/오프라인 여부를 입력하세요(on or off) : ")
        lv = int(input("1~4 레벨을 입력하세요 : "))
        # 온/오프라인, 레벨을 분리하여 팀에 넣는다.
        rank(name, lv, meet)
        
    print(on_team1, on_team2, on_team3, on_team4)
    print(off_team1, off_team2, off_team3, off_team4)

    on_team += [on_team1, on_team2, on_team3, on_team4]
    off_team += [off_team1, off_team2, off_team3, off_team4]

    for i in range(1, 5) : 
        print(f"on_team{i} = {on_team[i-1]}")
        print(f"off_team{i} = {off_team[i-1]}")
# Out:
# 학생수를 입력하세요 : 1
# 이름을 입력하세요 : 정상록
# 온/오프라인 여부를 입력하세요(on or off) : off
# 1~4 레벨을 입력하세요 : 3
# [] [] [] []
# [] [] ['정상록'] []
# on_team1 = []
# off_team1 = []
# on_team2 = []
# off_team2 = []
# on_team3 = []
# off_team3 = ['정상록']
# on_team4 = []
# off_team4 = []

# %%
a = 1
li1 = list()
print(li1)

def func(num) :
    global li1, a
    li1.append(1)
    global a 
    a = 3
    
func(1)
print(li1)
print(a)
# Out:
# []
# [1]
# 3

# %%
print_coin = lambda : print("비트코인")

print_coin()
# Out:
# 비트코인

# %%
# for i in range (100) : print_coin()

# %%
# 1
print_coin = lambda : print("비트코인")
print_coin()

# 1
# for i in range (100) : print_coin()

# 2
def print_coin(num) :
    for i in range(num) :
        print("비트코인")
# print_coin(100)

# 에러가 발생하는 이유
# 함수를 선언하기 전에 함수를 실행함

# 주어진 자연수의 홀,짝 분리
def distint(num) :
    if num % 2 == 0 :
        msg = "짝"
    else :
        msg = "홀"
    return msg
print(distint(10))

# 7. 입력되는 모든 수의 평균 값을 계산해 주는 함수를 작성합니다.
def avg(*args) : 
    return round(sum(args)/(len(args)-1), 2)
print(avg(43, 56, 35, 100, 25, 54, 14, 88))

# 8. input1 = input("첫번째 숫자:")
# input2 = input("두번째 숫자:")
# total = input1 + input2
# print("두 수의 합은 %s 입니다" % total)
# 3과 6을 입력했을 때 9가 아닌 36이 나옵니다. 이 프로그램의 오류를 수정합니다.
input1 = int(input("첫번째 숫자:"))
input2 = int(input("두번째 숫자:"))
total = input1 + input2
print("두 수의 합은 %s 입니다" % total)



# 9. f1 = open("test.txt", 'w')
# f1.write("Life is too short")
# f2 = open("test.txt", 'r')
# print(f2.read())
#  "Life is too short"라는 문장을 출력하게 수정
with open("test.txt", 'w') as f1 :
    f1.write("Life is too short")
with open("test.txt", 'r') as f1 :
    print(f1.read())





# 10. 사용자의 입력을 파일(encore.txt)에 저장하는 프로그램을 작성합니다. 
# 프로그램을 다시 실행하더라도 기존에 작성한 내용을 유지하고 새로 입력한 내용을 추가해야 합니다.
with open("encore.txt", "w") as f :
    f.write("예제 입니다.\n")
with open("encore.txt", "a") as f :
    f.write("추가 입력하는 예제 입니다.")
with open("encore.txt", "r") as f :
    line = f.readlines()
    for i in line :
        print(i.strip())
# Out:
# 짝
# 59.29
# 첫번째 숫자:3
# 두번째 숫자:3
# 두 수의 합은 6 입니다
# Life is too short
# 예제 입니다.
# 추가 입력하는 예제 입니다.

# %%
import csv
import os
import os.path

a = os.listdir("./encore_python/엔코아 파이썬 csv 실습 예제들/")
print(a)

file = "./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp.csv"
print(os.path.isfile(file))

# 인코딩 에러시 : utf8, utf16, utf32, cp949
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp.csv", "r", encoding="cp949") as f :
    line = f.readlines()
    line = line[7:-1].copy()
    for i in line :
        print(i.strip())
# Out:
# ['2021_jeju_temp.csv', 'month_temp.csv', 'pharm_20226.csv', '2021_jeju_humidity.csv', '2021_seoul_day_temp.csv', '2021_jeju_precipitation.csv']
# True
# 날짜,지점,평균기온(℃),최저기온(℃),최고기온(℃)
# 2021-01-01,108,-4.2,-9.8,1.6
# 2021-01-02,108,-5,-8.4,-1.4
# 2021-01-03,108,-5.6,-9.1,-2
# 2021-01-04,108,-3.5,-8.4,0.3
# 2021-01-05,108,-5.5,-9.9,-2.1
# 2021-01-06,108,-7.4,-12,-1.9
# 2021-01-07,108,-14.5,-16.5,-8.4
# 2021-01-08,108,-14.9,-18.6,-10.7
# 2021-01-09,108,-12.2,-16.6,-7.5
# 2021-01-10,108,-7.7,-12.8,-2.7
# 2021-01-11,108,-6.7,-9.6,-4
# 2021-01-12,108,-3.9,-9.3,-0.5
# 2021-01-13,108,2,-3,8.3
# 2021-01-14,108,1.7,-3.6,7
# 2021-01-15,108,4.5,-0.7,9.9
# 2021-01-16,108,-4.9,-8.7,-0.7
# 2021-01-17,108,-5.5,-10.8,-1.3
# 2021-01-18,108,-3.8,-9.1,0.2
# 2021-01-19,108,-6.3,-11.6,-0.2
# 2021-01-20,108,-0.1,-6.6,7.1
# 2021-01-21,108,4.5,2.5,7
# 2021-01-22,108,5.5,4.8,6.6
# 2021-01-23,108,7.6,4.8,12.2
# 2021-01-24,108,7.3,2.4,13.9
# 2021-01-25,108,7.9,3,13.9
# 2021-01-26,108,5.3,1.7,7.4
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp.csv", "r", encoding="cp949") as f :
    line = f.readlines()
    line = line[7:-1].copy()
    for i in line :
        temp = i.split(",")
        date = temp[0].split("-")
        a = temp[4]
        print(a, type(a))
        
        if temp[0].endswith("09-01") :
            print(f"{date[0]}년 {date[1]}월 {date[2]}일 서울의 평균기온은 {temp[2]}℃, 최저기온은{temp[3]}℃, 최고기온은{temp[4]}℃ 입니다.")

# 2021년 09월 01일 서울의 평균기온은 21.4℃, 최저기온은18.5℃, 최고기온은23.9℃ 입니다.
# Out:
# 최고기온(℃)
#  <class 'str'>
# 1.6
#  <class 'str'>
# -1.4
#  <class 'str'>
# -2
#  <class 'str'>
# 0.3
#  <class 'str'>
# -2.1
#  <class 'str'>
# -1.9
#  <class 'str'>
# -8.4
#  <class 'str'>
# -10.7
#  <class 'str'>
# -7.5
#  <class 'str'>
# -2.7
#  <class 'str'>
# -4
#  <class 'str'>
# -0.5
#  <class 'str'>
# 8.3
#  <class 'str'>
# 7
#  <class 'str'>
# 9.9
#  <class 'str'>
# -0.7
#  <class 'str'>
# -1.3
#  <class 'str'>
# 0.2
#  <class 'str'>
# -0.2
#  <class 'str'>
# 7.1
#  <class 'str'>
# 7
#  <class 'str'>
# 6.6
#  <class 'str'>
# 12.2
#  <class 'str'>
# 13.9
#  <class 'str'>
# 13.9
#  <class 'str'>
# 7.4
#  <class 'str'>
# 6.5
#  <class 'str'>
# 1.4
#  <class 'str'>
# -4.9
#  <class 'str'>
# 5.2
#  <class 'str'>
# 8.7
#  <class 'str'>
# 9.5
#  <class 'str'>
# -2.4
#  <class 'str'>
# 1.4
#  <class 'str'>
# 0.7
#  <class 'str'>
# 6.7
#  <class 'str'>
# 9.5
#  <class 'str'>
# 7.7
#  <class 'str'>
# 0.2
#  <class 'str'>
# 4.7
#  <class 'str'>
# 7.2
#  <class 'str'>
# 10.9
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp.csv", "r", encoding="cp949") as f :
    line = f.readlines()
    line2 = line[7:8].copy()
    line = line[8:-1].copy()
    line3 = line2[0].split(",")

    print("{0:^11}|{1:^7}|{2:^8}|{3:^7}|".format(line3[0].strip(), line3[3].strip(), line3[4].strip(), "일교차"))
    
    for i in line :
        temp = i.split(",")
        date = temp[0].split("-")
        temp_range = float(temp[4]) - float(temp[3])
        print("{0:^12}|{1:^9}|{2:^9}|{3:^9}| ".format(temp[0], temp[3], temp[4].strip(), round(temp_range, 2)))

# 2021년 09월 01일 서울의 평균기온은 21.4℃, 최저기온은18.5℃, 최고기온은23.9℃ 입니다.
# Out:
#     날짜     |최저기온(℃)|최고기온(℃) |  일교차  |
#  2021-01-01 |  -9.8   |   1.6   |  11.4   |
#  2021-01-02 |  -8.4   |  -1.4   |   7.0   |
#  2021-01-03 |  -9.1   |   -2    |   7.1   |
#  2021-01-04 |  -8.4   |   0.3   |   8.7   |
#  2021-01-05 |  -9.9   |  -2.1   |   7.8   |
#  2021-01-06 |   -12   |  -1.9   |  10.1   |
#  2021-01-07 |  -16.5  |  -8.4   |   8.1   |
#  2021-01-08 |  -18.6  |  -10.7  |   7.9   |
#  2021-01-09 |  -16.6  |  -7.5   |   9.1   |
#  2021-01-10 |  -12.8  |  -2.7   |  10.1   |
#  2021-01-11 |  -9.6   |   -4    |   5.6   |
#  2021-01-12 |  -9.3   |  -0.5   |   8.8   |
#  2021-01-13 |   -3    |   8.3   |  11.3   |
#  2021-01-14 |  -3.6   |    7    |  10.6   |
#  2021-01-15 |  -0.7   |   9.9   |  10.6   |
#  2021-01-16 |  -8.7   |  -0.7   |   8.0   |
#  2021-01-17 |  -10.8  |  -1.3   |   9.5   |
#  2021-01-18 |  -9.1   |   0.2   |   9.3   |
#  2021-01-19 |  -11.6  |  -0.2   |  11.4   |
#  2021-01-20 |  -6.6   |   7.1   |  13.7   |
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp2.csv", "w", encoding="cp949") as f :


    f.write("{0:^11}|{1:^7}|{2:^8}|{3:^7}|\n".format(line3[0].strip(), line3[3].strip(), line3[4].strip(), "일교차"))
    f.write("-"*40 + "\n")
    for i in line :
        temp = i.split(",")
        date = temp[0].split("-")
        temp_range = float(temp[4]) - float(temp[3])
        f.write("{0:^12}|{1:^9}|{2:^9}|{3:^9}|\n".format(temp[0], temp[3], temp[4].strip(), round(temp_range, 2)))

# 2021년 09월 01일 서울의 평균기온은 21.4℃, 최저기온은18.5℃, 최고기온은23.9℃ 입니다.

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp3.csv", "w", encoding="cp949") as f :

    f.write("{0},{1},{2},{3}\n".format(line3[0].strip(), line3[3].strip(), line3[4].strip(), "일교차"))

    for i in line :
        temp = i.split(",")
        date = temp[0].split("-")
        temp_range = float(temp[4]) - float(temp[3])
        f.write("{0},{1},{2},{3}\n".format(temp[0], temp[3], temp[4].strip(), round(temp_range, 2)))

# 2021년 09월 01일 서울의 평균기온은 21.4℃, 최저기온은18.5℃, 최고기온은23.9℃ 입니다.

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_seoul_day_temp.csv", "r", encoding="cp949") as f :
    line = f.readlines()
    line = line[8:-1].copy()
    
    month = input("월을 입력하세요(ex : 01 ~ 12) : ")
    
    temp = []
    total = 0
    for i in line :
        if i.split(",")[0].endswith(month, 0, 7) :
            temp.append(float(i.split(",")[2]))
    total = sum(temp)

    z = 1
    while True :
        if z == len(temp) :
            break
        if z % 10 == 0:
            print("{0:^5}".format(temp[z-1]))
            z += 1
            continue
        print("{0:^5}".format(temp[z-1]), end = " ")
        z += 1

    print(f"\n%s월의 평균 기온 : %.2f" % (month, round(total/len(temp), 2)))
    
# 월을 입력하세요(ex : 01 ~ 12) : 02
#  5.0  -5.6  -3.2  -3.6   1.4   6.8   3.6  -3.1  -0.9   3.4 
#  5.5   6.5   7.6   9.5   1.2  -5.1  -8.3  -5.8   1.6   8.8 
# 10.8   7.8   0.0   2.9   4.2   8.2   9.5  
# 02월의 평균 기온 : 2.73

# %%
s = 0
cnt = 0
for i in line:
    temp = i.split(',')
    if temp[0].startswith('2021-09'):
        temp[2] = float(temp[2])
        print(temp[2], end= ' ')
        s += temp[2]
        cnt +=1
avg = round(s/cnt, 2)
print('9월 평균 기온:', avg)

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/pharm_20226.csv", "r") as f :
    pharm = f.readlines()
#     1, 5, 6, 10, -4, -3
    pharm_new = []
    for i in pharm[1:] : 
        addr = i.split('"')

        new = i.split(",")
        if new[-4] == "" :
            pharm_new.extend([[new[1], new[5], new[7], new[10], new[-4], new[-3]]])

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/pharm_20226.csv", "r") as f :
    pharm = f.readlines()
    pharm_new = []
    name = input("병원명 : ")
    region = input("시도명 : ")
    for i in pharm[1:] : 
    
        info = i.split(',')
        if region in i and name in i : 
            addr = info[-5]
            print(f"{name}의 주소 : {addr}")
            
# 병원을 입력하세요 : 독산종로약국
# 독산종로약국의 주소 : 서울특별시 금천구 독산로 360 (독산동)
# Out:
# 병원명 : 독산종로약국
# 시도명 : 서울
# 독산종로약국의 주소 : 서울특별시 금천구 독산로 360 (독산동)

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/pharm_20226.csv", "r") as f :
    pharm = f.readlines()
    pharm_new = []
    name = input("건물명 : ")
    region = input("시도명 : ")
    
    data = f" {region}내 {name} 건물 현황 "
    print("{0:*^30}\n{1:*^40}".format(data, "*"))
    
    for i in pharm[1:] : 
        info = i.split(',')
        name = info[1] 
        tel = info[-4]
        open_day = info[-3]
        
        if '"' in i :
            addr = i.split('"')[1]
        else : 
            addr = info[-5]
    
        if region in i and name in i : 
            print(f"약   국 : {name}\n주   소 : {addr}\n전화번호 : {tel}\n개업일자 : {open_day}")
            print("{0:-^40}".format("-"))
            
            
# 건물명 : 로얄스포츠
# 시도명 : 수지
# ****** 수지내 로얄스포츠 건물 현황 *******
# ****************************************
# 약   국 : 베델약국
# 주   소 : 경기도 용인시 수지구 문인로 59 107호 (풍덕천동, 삼익상가)
# 전화번호 : 031-276-0050
# 개업일자 : 2003.3.22
# ----------------------------------------
# 약   국 : 예쁜약국
# 주   소 : 경기도 용인시 수지구 신봉2로 2 센트럴500 223호 (신봉동)
# 전화번호 : 031-893-0750
# 개업일자 : 2018.4.30
# ----------------------------------------
# 약   국 : 희망약국
# 주   소 : 경기도 용인시 수지구 풍덕천로 119 118호 (풍덕천동, 로얄스포츠센터)
# 전화번호 : 031-264-4288
# 개업일자 : 2017.2.16
# ----------------------------------------
# Out:
# 건물명 : 로얄스포츠
# 시도명 : 수지
# ****** 수지내 로얄스포츠 건물 현황 *******
# ****************************************
# 약   국 : 베델약국
# 주   소 : 경기도 용인시 수지구 문인로 59 107호 (풍덕천동, 삼익상가)
# 전화번호 : 031-276-0050
# 개업일자 : 2003.3.22
# ----------------------------------------
# 약   국 : 예쁜약국
# 주   소 : 경기도 용인시 수지구 신봉2로 2 센트럴500 223호 (신봉동)
# 전화번호 : 031-893-0750
# 개업일자 : 2018.4.30
# ----------------------------------------
# 약   국 : 희망약국
# 주   소 : 경기도 용인시 수지구 풍덕천로 119 118호 (풍덕천동, 로얄스포츠센터)
# 전화번호 : 031-264-4288
# 개업일자 : 2017.2.16
# ----------------------------------------
# 약   국 : 세종옵티마약국
# 주   소 : 경기도 용인시 수지구 수지로 62 (상현동)
# 전화번호 : 031-261-8027
# 개업일자 : 2007.4.24
# ----------------------------------------
# 약   국 : 새보건약국
# 주   소 : 경기도 용인시 수지구 풍덕천로130번길 4 1층 (풍덕천동)
# 전화번호 : 031-266-2997
# 개업일자 : 2014.9.26
# ----------------------------------------
# 약   국 : 푸른솔약국
# 주   소 : 경기도 용인시 수지구 광교중앙로 301 (상현동)
# 전화번호 : 031-215-5413
# 개업일자 : 2012.8.1
# ----------------------------------------
# 약   국 : 광교윤하약국
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/pharm_20226.csv", "r") as f :
    pharm = f.readlines()
    year = int(input("몇년 이후에 건설했는가 :  : "))
    region = input("시도명 : ")
    
    num = 0
    total_num = 0
    for i in pharm[1:] : 
        info = i.split(',')
        
        if '"' in i :
            addr = i.split('"')[1]
        else : 
            addr = info[-5]
        
        if region in addr :
            total_num += 1
            
            if info[-3].split(".")[0] == "" :
                continue
            op_year = int(info[-3].split(".")[0])
            info[-3][:4]

            if year <= op_year : 
                num += 1
                
    print(f"{region} 전체 약국 수 : {total_num}\n{year}년 이후 개설된 {region}의 약국 수 : {num}")
# Out:
# 몇년 이후에 건설했는가 :  : 2020
# 시도명 : 서울
# 서울 전체 약국 수 : 5466
# 2020년 이후 개설된 서울의 약국 수 : 869

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/pharm_20226.csv", "r") as f :
    pharm = f.readlines()
    pharm_new = []
    region = input("도시를 입력하세요 : ")
    start = int(input("시작 년도 : "))
    end = int(input("끝 년도 : "))
    graph = []
    
    for i in range(start, end+1) :
        graph.append({i : 0})
        
    
    data = f"{region}의 {start}부터 {end}까지의 개원 현황"
    print("{0:*^30}\n{1:*^40}".format(data, "*"))
    
    for i in pharm[1:] : 
        info = i.split(',')
        
        # 주소정립
        if '"' in i :
            addr = i.split('"')[1]
        else : 
            addr = info[-5]
        
        # 주소 확인
        if region in addr : 
            # 설립일 유무 확인
            if info[-3].split(".")[0] == "" :
                continue
            op_year = int(info[-3].split(".")[0])

            for y in range(len(graph)) : 
                for key, value in graph[y].items() :
                    if key == op_year :
                        graph[y][key] += 1
    
    # 그래프로 출력하기
    for i in range(len(graph)) :
        for key, value in graph[i].items() :
            print(f"{key} {'.' * int(value)}")
    
    # 숫자로 출력하기
    for i in range(len(graph)) :
        for key, value in graph[i].items() :
            print(f"{key} : {value}")
# Out:
# 도시를 입력하세요 : 서울
# 시작 년도 : 1960
# 끝 년도 : 2022
# ***서울의 1960부터 2022까지의 개원 현황***
# ****************************************
# 1960
# 1961
# 1962 .
# 1963 .
# 1964 ..
# 1965 ...
# 1966 ....
# 1967 ......
# 1968 ......
# 1969 ........
# 1970 .........
# 1971 ...........
# 1972 ..............
# 1973 ....................
# 1974 .........................
# 1975 .......................
# 1976 ............................
# 1977 ...............................
# 1978 .......................
# 1979 ..................
# 1980 ...................................
# 1981 .................................
# 1982 ..............................................
# 1983 .............................................
# 1984 ............................................
# 1985 ......................................
# 1986 .................................
# 1987 ....................................
# 1988 .......................................
# 1989 ................................
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_jeju_precipitation.csv", "r", encoding="cp949") as f :
    line2 = f.readlines()
    for i in line[8:] :
        print(i)
# 날짜,지점,강수량(mm)
# Out:
# 2021-01-01,184,0
#
# 2021-01-02,184,0
#
# 2021-01-03,184,
#
# 2021-01-04,184,
#
# 2021-01-05,184,0
#
# 2021-01-06,184,0.6
#
# 2021-01-07,184,7.9
#
# 2021-01-08,184,6.1
#
# 2021-01-09,184,0.9
#
# 2021-01-10,184,0
#
# 2021-01-11,184,10.8
#
# 2021-01-12,184,1.2
#
# 2021-01-13,184,
#
# 2021-01-14,184,
#
# 2021-01-15,184,
#
# 2021-01-16,184,
#
# 2021-01-17,184,2
#
# 2021-01-18,184,0
#
# 2021-01-19,184,
#
# 2021-01-20,184,
#
# 2021-01-21,184,0.5
#
# 2021-01-22,184,8.2
#
# 2021-01-23,184,57.8
#
# 2021-01-24,184,0.2
#
# 2021-01-25,184,
#
# 2021-01-26,184,19.7
#
# 2021-01-27,184,
#
# 2021-01-28,184,0.5
#
# 2021-01-29,184,0.2
#
# 2021-01-30,184,
#
# 2021-01-31,184,0
#
# 2021-02-01,184,22.4
#
# 2021-02-02,184,
#
# 2021-02-03,184,
#
# 2021-02-04,184,0.1
#
# 2021-02-05,184,0
#
# 2021-02-06,184,
#
# 2021-02-07,184,
#
# 2021-02-08,184,
#
# 2021-02-09,184,
#
# 2021-02-10,184,
#
# 2021-02-11,184,
#
# 2021-02-12,184,
#
# 2021-02-13,184,
#
# 2021-02-14,184,2.4
#
# 2021-02-15,184,0
#
# 2021-02-16,184,0
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_jeju_temp.csv", "r", encoding="cp949") as f :
    line1 = f.readlines()
    for i in line[8:-1] :
        print(i)
#         날짜,지점,평균기온(℃),최저기온(℃),최고기온(℃), [17]시작
# Out:
# 2021-01-01,184,0
#
# 2021-01-02,184,0
#
# 2021-01-03,184,
#
# 2021-01-04,184,
#
# 2021-01-05,184,0
#
# 2021-01-06,184,0.6
#
# 2021-01-07,184,7.9
#
# 2021-01-08,184,6.1
#
# 2021-01-09,184,0.9
#
# 2021-01-10,184,0
#
# 2021-01-11,184,10.8
#
# 2021-01-12,184,1.2
#
# 2021-01-13,184,
#
# 2021-01-14,184,
#
# 2021-01-15,184,
#
# 2021-01-16,184,
#
# 2021-01-17,184,2
#
# 2021-01-18,184,0
#
# 2021-01-19,184,
#
# 2021-01-20,184,
#
# 2021-01-21,184,0.5
#
# 2021-01-22,184,8.2
#
# 2021-01-23,184,57.8
#
# 2021-01-24,184,0.2
#
# 2021-01-25,184,
#
# 2021-01-26,184,19.7
#
# 2021-01-27,184,
#
# 2021-01-28,184,0.5
#
# 2021-01-29,184,0.2
#
# 2021-01-30,184,
#
# 2021-01-31,184,0
#
# 2021-02-01,184,22.4
#
# 2021-02-02,184,
#
# 2021-02-03,184,
#
# 2021-02-04,184,0.1
#
# 2021-02-05,184,0
#
# 2021-02-06,184,
#
# 2021-02-07,184,
#
# 2021-02-08,184,
#
# 2021-02-09,184,
#
# 2021-02-10,184,
#
# 2021-02-11,184,
#
# 2021-02-12,184,
#
# 2021-02-13,184,
#
# 2021-02-14,184,2.4
#
# 2021-02-15,184,0
#
# 2021-02-16,184,0
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/2021_jeju_humidity.csv", "r", encoding="cp949") as f :
    line = f.readlines()
    for i in line :
        print(i)
#         지점번호,지점명,일시,평균습도(%rh),최저습도(%rh)
# Out:
# 조건별분석
#
# [검색조건]
#
# ,분류: 지상
#
# ,요소 : 습도
#
# ,검색구분 : 일
#
# ,지역/지점명 : 제주
#
# ,기간 : 2021 ~ 2021년 01 ~ 12월 01 ~ 31일
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		지점번호,지점명,일시,평균습도(%rh),최저습도(%rh)
#
# 		184,제주,2021-01-01,54.4,46.0
#
# 		184,제주,2021-01-02,56.4,43.0
#
# 		184,제주,2021-01-03,57.0,48.0
#
# 		184,제주,2021-01-04,57.8,48.0
#
# 		184,제주,2021-01-05,66.0,57.0
#
# 		184,제주,2021-01-06,60.8,41.0
#
# 		184,제주,2021-01-07,76.5,49.0
#
# 		184,제주,2021-01-08,74.9,43.0
#
# 		184,제주,2021-01-09,71.4,52.0
#
# 		184,제주,2021-01-10,62.9,49.0
#
# 		184,제주,2021-01-11,79.0,50.0
#
# 		184,제주,2021-01-12,62.3,49.0
#
# 		184,제주,2021-01-13,48.9,39.0
#
# 		184,제주,2021-01-14,62.5,50.0
#
# 		184,제주,2021-01-15,67.9,46.0
#
# 		184,제주,2021-01-16,64.6,57.0
#
# 		184,제주,2021-01-17,69.0,47.0
#
# 		184,제주,2021-01-18,50.6,39.0
#
# 		184,제주,2021-01-19,53.3,37.0
#
# 		184,제주,2021-01-20,58.3,39.0
#
# 		184,제주,2021-01-21,66.8,45.0
#
# 		184,제주,2021-01-22,91.4,80.0
#
# 		184,제주,2021-01-23,90.0,78.0
#
# ...

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/jeju.csv", "w", encoding="cp949") as f :
    jeju = [["날짜", "평균기온(℃)", "최고기온(℃)", "최저기온(℃), 강수량(mm)"]]
    
    for i in line1[8:-1] : 
        info = i.split(",")
        day = info[0]
        avg_temp = info[2]
        high_temp = info[4].strip()
        low_temp = info[3]
        jeju.append([day, avg_temp, high_temp, low_temp])

# %%
with open("./encore_python/엔코아 파이썬 csv 실습 예제들/jeju.csv", "w", encoding="cp949") as f :

    y = 1
    for i in line2[8:] : 
        info = i.split(",")
        rainfall = info[2].strip()
#         print(rainfall)
        
        jeju[y].append(rainfall)
        y += 1

# %%
jeju
# Out:
# [['날짜', '평균기온(℃)', '최고기온(℃)', '최저기온(℃), 강수량(mm)'],
#  ['2021-01-01', '5.5', '7.2', '4', '0'],
#  ['2021-01-02', '5.9', '8.4', '2.8', '0'],
#  ['2021-01-03', '4.5', '6.3', '2.7', ''],
#  ['2021-01-04', '5.9', '9.2', '2.2', ''],
#  ['2021-01-05', '5.6', '9', '2.6', '0'],
#  ['2021-01-06', '4', '5.6', '1.7', '0.6'],
#  ['2021-01-07', '-1.1', '4.4', '-3.1', '7.9'],
#  ['2021-01-08', '-1.1', '1', '-2.7', '6.1'],
#  ['2021-01-09', '1.2', '3.1', '-2.1', '0.9'],
#  ['2021-01-10', '3.6', '5.1', '0.8', '0'],
#  ['2021-01-11', '3.4', '5.1', '1.5', '10.8'],
#  ['2021-01-12', '4.7', '6.4', '2.6', '1.2'],
#  ['2021-01-13', '10', '13.6', '5.2', ''],
#  ['2021-01-14', '10.8', '15.4', '7.9', ''],
#  ['2021-01-15', '12.1', '18.2', '7.7', ''],
#  ['2021-01-16', '5.1', '8.6', '2.8', ''],
#  ['2021-01-17', '3.1', '4.4', '1.2', '2'],
#  ['2021-01-18', '6.6', '9.9', '3.1', '0'],
#  ['2021-01-19', '4', '6.3', '2', ''],
#  ['2021-01-20', '9.2', '15.9', '3.8', ''],
# ...

# %%
low_list = []

for i in jeju[1:] :
    low_list.append(float(i[3]))
    
print(f"2021 제주 최저 기온 {min(low_list)}, 평균 최저 기온 : {round(sum(low_list) / len(low_list), 2)}")




for n in range(1, 13) :
    month_avg = []
    for i in jeju[1:] :
        if int(i[0].split("-")[1]) == n :
            month_avg.append(float(i[3]))
    print(f"{n}월의 평균 온도 : {round(sum(month_avg) / len(month_avg), 2)}")
    

    

            

    

# print(month_avg_list)
# Out:
# 2021 제주 최저 기온 -3.1, 평균 최저 기온 : 14.67
# 1월의 평균 온도 : 3.92
# 2월의 평균 온도 : 6.38
# 3월의 평균 온도 : 9.3
# 4월의 평균 온도 : 12.23
# 5월의 평균 온도 : 15.64
# 6월의 평균 온도 : 20.79
# 7월의 평균 온도 : 25.47
# 8월의 평균 온도 : 25.02
# 9월의 평균 온도 : 22.47
# 10월의 평균 온도 : 17.12
# 11월의 평균 온도 : 10.93
# 12월의 평균 온도 : 6.25

# %%
result = 0

def add(num) : 
    global result 
    result += num 
    return result
    
print(add(3))
print(add(4))

# 3
# 7
# Out:
# 3
# 7

# %%
class MyClass :
    number = 100
    
    def inc_10(self) :
        MyClass.number += 10
        
    def inc_20(sefl) :
        MyClass.number += 20
        
m1 = MyClass()
m1.inc_10()
print(m1.number)
# 110

m2 = MyClass()
m2.inc_10()
print(m2.number)
#120
# Out:
# 110
# 120

# %%
class MyClass :

    def one(self, number):
        self.number = number #인스턴스 속성
    
    def inc_10(self) :
        self.number += 10 #인스턴스 속성
        
    def inc_20(self) :
        self.number += 20 #인스턴스 속성
        
m3 = MyClass()
m3.one(100) # 인스턴스 속성에 초기값 선언
m3.inc_10()
print(m3.number)
# 110

m4 = MyClass()
m4.one(1000) # 인스턴스 속성에 초기값 선언
m4.inc_20()
print(m4.number)
# 1020

m5 = MyClass()
m5.one(0)
m5.inc_20()
print(m5.number)
# 20
# Out:
# 110
# 1020
# 20

# %%
class Encore : 
    def f(self, a, b) :
        self.a = a
        self.b = b
        
x = Encore()
y = Encore()
x.f(5, 8)
y.f(5, 10)
print(x.a, x.b, y.a, y.b)
# 5 8 5 10
# Out:
# 5 8 5 10

# %%
class FourCal() :
    def setData(self, a, b) :
        self.a = a
        self.b = b
        
    def add(self):
        return self.a + self.b
    def mul(self) :
        return self.a * self.b
    def sub(self) :
        return self.a - self.b
    def div(self) : 
        return self.a / self.b
    
a = FourCal()
a.setData(3, 5)
print(a.add())
print(a.mul())
print(a.sub())
print(a.div())

# 8
# 15
# -2
# 0.6
# Out:
# 8
# 15
# -2
# 0.6

# %%
class Woman : 
    addr = "서울"
    def __init__(self, name) :
        self.name = name
        
w1 = Woman("영미")
print(w1.name, w1.addr)
# 영미 서울

w2 = Woman("수자")
Woman.addr = "뉴욕"
print(w1.name, w1.addr)
# 영미 뉴욕
# Out:
# 영미 서울
# 영미 뉴욕
